# %% [markdown]
# <img align = "center" src= "images/mu_logo.png" width="300"/>
#
# ---
#
# <h1><b>Data Science Day</b></h1>
# <h3>Friday, December 1, 2023 </h3>
#
# ---
#
# <h2> <b> Presenters:</b> </h2>
# <h3> <b> Andrew Casanova, </b> Senior Data Scientist, Black Cape IO </h3>
# <h3> <b> Lindsey Tagg, </b> Senior Data Scientist, Deloitte LLP </h3>
#
# ---
#
# <h2> Itinerary: </h2>
#
# <h3> I. What is Data Science? (Andrew Casanova) </h3>
# <h3> II. Detecting Fraud, Waste & Abuse. (Lindsey Tagg) </h3>
# <h3> III. Data Science Models in Action. (Andrew & Lindsey) </h3>

# %% [markdown]
# # I. What is Data Science?
# <div>
# <img src= "images/what_is_data_science.png" width="800"/>
# </div>

# %% [markdown]
# ## What's the difference?
# <div>
# <img src="images/whats_the_difference.png" width="800"/>
# </div>

# %% [markdown]
# ## The Workflow
# <div>
# <img src="images/the_workflow.png" width="700"/>
# </div>

# %% [markdown]
# ## Popular Methods
# <div>
# <img src="images/popular_methods.png" width="900"/>
# </div>

# %% [markdown]
# ## How does it work?
#
# <div>
#     <center> <h3> Supervised Learning </h3></center>
#     <img src="images/supervised_learning.png" width="900"/>
#     <center><h3> Unsupervised Learning </h3></center>
#     <img src="images/unsupervised_learning.png" width = "900"/>
# </div>

# %% [markdown]
# ## Using Data Science Has Consequences
# <div>
# <img src="images/consequences.png" width="200"/>
# </div>
#
# * Not understanding the problem
# * Measuring Error
# * Converting People into Numbers
# * Model Interpretability
# * Causal Modelling
# * Bias & Ethics

# %% [markdown]
# ## Why Data Science is Awesome!
# * Have a HUGE impact on your company and the planet!
# * Growing Demand
# * Data Science Salaries
# * An Ever-Evolving Field
# * Diverse Career Growth Options
#
# https://www.discoverdatascience.org/articles/top-reasons-to-become-a-data-scientist/#:~:text=You'll%20gain%20a%20wide,%2C%20big%20data%2C%20and%20more.

# %% [markdown]
# ## What Makes a Great Data Scientist?
#
# * They care about the work
# * They are motivated and life-long learners
# * They enjoy problem-solving
# * They are effective communicators

# %% [markdown]
# # II. Detecting Fraud, Waste & Abuse

# %% [markdown]
# ## Be the Fraudster
#
# What is the scientific method? 5 minutes
# * Give an image of this and ask split groups
#     * Fraudsters vs Fraud Evaluators
#     * If you wanted to get away with Fraud, how would you solve backwards and try to identify the problem.
#     * It’s common in fraud, one is identify theft and the other is identity simulation.
#         * We can bring up metadata, submission time series
#
# Why do we care?
# * Having tools to uncover what’s not obvious through manual review/plain sight is impactful and empowering for businesses, agencies, personal research.
# * Provides structure to unstructured investigation
#
# Data Science is a subset of tools that you pull out of toolset when the situation makes sense. Know when to use which tools to evaluate the situation.
#
# 2-3 Models to show input and the outputs (Difference in how
# Ethics of the outputs of the models
#
# Final Statements 2-3 minutes / each.

# %% [markdown]
# # III. Data Science Models in Action

# %% [markdown]
# ## Predicting Forest Fires
# ### Data Understanding:
#
# |Column Name|Definition|
# |:--:|:--|
# | X | x-axis spatial coordinate within the Montesinho park map: 1 to 9|
# | Y | y-axis spatial coordinate within the Montesinho park map: 2 to 9|
# | month | month of the year: ‘jan’ to ‘dec’|
# | day | day of the week: ‘mon’ to ‘sun’|
# | FFMC | FFMC (Fine Fuel Moisture Code) index from the FWI system: 18.7 to 96.20|
# | DMC | DMC (Duff Moisture Code) index from the FWI system: 1.1 to 291.3|
# | DC | DC (Drought Code) index from the FWI system: 7.9 to 860.6|
# | ISI | ISI (Initial Spread Index) index from the FWI system: 0.0 to 56.10|
# | temp | temperature in Celsius degrees: 2.2 to 33.30|
# | RH | relative humidity in %: 15.0 to 100|
# | wind | wind speed in km/h: 0.40 to 9.40|
# | rain | outside rain in mm/m2 : 0.0 to 6.4|
# | area | the burned area of the forest (in ha): 0.00 to 1090.84|

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

from IPython.display import IFrame

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import tensorflow as tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model

# %%
# Data found: 
df = pd.read_csv("data/forestfires.csv")
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
#Encode Months as numeric values
month_vals = {'jan': 1,'feb': 2,'mar': 3,'apr': 4,'may': 5,'jun': 6,'jul': 7,'aug': 8,'sep': 9,'oct': 10,'nov': 11,'dec': 12}
df['month'] = df['month'].map(month_vals)

# %%
# Data Preprocessing
df['size_category'] = np.where(df['area'] > 6, '1', '0')
df['size_category']= pd.to_numeric(df['size_category'])

# converting to is weekend
df['day'] = ((df['day'] == 'sun') | (df['day'] == 'sat'))

# renaming column
df = df.rename(columns = {'day' : 'is_weekend'})

# visualizing
sns.countplot(df['is_weekend'])
plt.title('Count plot of weekend vs weekday')
# Out:
# Text(0.5, 1.0, 'Count plot of weekend vs weekday')

# %%
# natural logarithm scaling (+1 to prevent errors at 0)
df.loc[:, ['rain', 'area']] = df.loc[:, ['rain', 'area']].apply(lambda x: np.log(x + 1), axis = 1)

# visualizing
fig, ax = plt.subplots(2, figsize = (5, 8))
ax[0].hist(df['rain'])
ax[0].title.set_text('histogram of rain')
ax[1].hist(df['area'])
ax[1].title.set_text('histogram of area')

# %%
# Assign feature columns and target variable (labels)
features = df.drop(['size_category'], axis = 1)
labels = df['size_category'].values.reshape(-1, 1)

#Set the train/test split using 80/20
X_train, X_test, y_train, y_test = train_test_split(features,labels, test_size = 0.2, random_state = 42)

# %%
# fitting scaler
sc_features = StandardScaler()

# transforming features
X_test = sc_features.fit_transform(X_test)
X_train = sc_features.transform(X_train)

# features
X_test = pd.DataFrame(X_test, columns = features.columns)
X_train = pd.DataFrame(X_train, columns = features.columns)

# labels
y_test = pd.DataFrame(y_test, columns = ['size_category'])
y_train = pd.DataFrame(y_train, columns = ['size_category'])
X_train.head()
# Out:
#           X         Y     month  is_weekend      FFMC       DMC        DC  \
# 0 -0.293766 -0.927776  0.672240    1.404076  0.342959 -0.060220  0.867158
# 1 -0.293766 -0.161993  0.672240   -0.712212 -0.057456  0.370353  0.600021
# 2 -1.130796  0.603791  0.232536   -0.712212  0.312158  0.834731  0.483714
# 3 -0.712281 -0.161993  0.232536   -0.712212  1.544206  1.341810  0.537142
# 4  0.124750 -0.161993 -2.405688    1.404076 -1.320305 -1.602809 -2.022846
#
#         ISI      temp        RH      wind      rain      area
# 0 -0.249015  0.784070 -1.071784 -0.054362 -0.137348  0.219260
# 1 -0.465731 -0.203920 -0.279375 -1.042369 -0.137348  0.177491
# 2  0.664288  0.221938  0.248898 -0.054362 -0.137348  0.180797
# 3  0.664288  2.283090 -1.071784 -1.042369 -0.137348  1.087255
# 4 -0.945602 -1.106740  0.645102 -1.042369 -0.137348  0.578923

# %%
def baseline_model():
    model = Sequential()
    # input layer + 1st hidden layer
    model.add(Dense(6, input_dim=13, activation='relu'))
    # 2nd hidden layer
    model.add(Dense(6, activation='relu'))
    # output layer
    model.add(Dense(6, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    print(model.summary())
    return(model)

# Define the baseline model
model = baseline_model()

# Compile Model
model.compile(optimizer = 'adam', metrics=['accuracy'], loss ='binary_crossentropy')

# Train Model
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), batch_size = 10, epochs = 100)

# Evaluate the Baseline Model
_, train_acc = model.evaluate(X_train, y_train, verbose=0)
_, valid_acc = model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Valid: %.3f' % (train_acc, valid_acc))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 84
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 6)                 42
#
#  dropout (Dropout)           (None, 6)                 0
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 175
# Trainable params: 175
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 42/42 [==============================] - 1s 4ms/step - loss: 2.3183 - accuracy: 0.4625 - val_loss: 0.7687 - val_accuracy: 0.3846
# Epoch 2/100
# 42/42 [==============================] - 0s 1ms/step - loss: 2.0473 - accuracy: 0.4673 - val_loss: 0.7013 - val_accuracy: 0.4615
# Epoch 3/100
# 42/42 [==============================] - 0s 1ms/step - loss: 2.1713 - accuracy: 0.4649 - val_loss: 0.6731 - val_accuracy: 0.5385
# Epoch 4/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.7337 - accuracy: 0.5472 - val_loss: 0.6480 - val_accuracy: 0.6346
# Epoch 5/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.5449 - accuracy: 0.5569 - val_loss: 0.6292 - val_accuracy: 0.6538
# Epoch 6/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.5334 - accuracy: 0.5811 - val_loss: 0.6162 - val_accuracy: 0.6827
# Epoch 7/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.3108 - accuracy: 0.5763 - val_loss: 0.6108 - val_accuracy: 0.6827
# Epoch 8/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.3576 - accuracy: 0.5932 - val_loss: 0.7000 - val_accuracy: 0.7019
# Epoch 9/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.0482 - accuracy: 0.6102 - val_loss: 0.6905 - val_accuracy: 0.7212
# Epoch 10/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.2319 - accuracy: 0.6320 - val_loss: 0.6885 - val_accuracy: 0.7212
# Epoch 11/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.0956 - accuracy: 0.6901 - val_loss: 0.6859 - val_accuracy: 0.7212
# Epoch 12/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.2434 - accuracy: 0.6150 - val_loss: 0.6819 - val_accuracy: 0.7212
# Epoch 13/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.1082 - accuracy: 0.6780 - val_loss: 0.6788 - val_accuracy: 0.7212
# Epoch 14/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.0631 - accuracy: 0.6271 - val_loss: 0.6759 - val_accuracy: 0.7212
# Epoch 15/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.9251 - accuracy: 0.6683 - val_loss: 0.6740 - val_accuracy: 0.7212
# Epoch 16/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.1237 - accuracy: 0.6392 - val_loss: 0.6701 - val_accuracy: 0.7212
# Epoch 17/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.9578 - accuracy: 0.6271 - val_loss: 0.5605 - val_accuracy: 0.7115
# Epoch 18/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.0015 - accuracy: 0.6344 - val_loss: 0.5540 - val_accuracy: 0.7308
# Epoch 19/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.9754 - accuracy: 0.6465 - val_loss: 0.5519 - val_accuracy: 0.7308
# Epoch 20/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.9864 - accuracy: 0.6489 - val_loss: 0.5533 - val_accuracy: 0.7308
# Epoch 21/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.2051 - accuracy: 0.6586 - val_loss: 0.5513 - val_accuracy: 0.7404
# Epoch 22/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.9177 - accuracy: 0.6199 - val_loss: 0.5483 - val_accuracy: 0.7308
# Epoch 23/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.0452 - accuracy: 0.6344 - val_loss: 0.5472 - val_accuracy: 0.7404
# Epoch 24/100
# 42/42 [==============================] - 0s 1ms/step - loss: 1.1587 - accuracy: 0.6804 - val_loss: 0.5484 - val_accuracy: 0.7308
# Epoch 25/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.8256 - accuracy: 0.7046 - val_loss: 0.5511 - val_accuracy: 0.7404
# Epoch 26/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.8768 - accuracy: 0.6683 - val_loss: 0.5553 - val_accuracy: 0.7500
# Epoch 27/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.8370 - accuracy: 0.6755 - val_loss: 0.5439 - val_accuracy: 0.7500
# Epoch 28/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.8053 - accuracy: 0.7094 - val_loss: 0.6439 - val_accuracy: 0.7500
# Epoch 29/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.9602 - accuracy: 0.6755 - val_loss: 0.6369 - val_accuracy: 0.7500
# Epoch 30/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.7062 - accuracy: 0.7070 - val_loss: 0.6315 - val_accuracy: 0.7500
# Epoch 31/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.8050 - accuracy: 0.7119 - val_loss: 0.5211 - val_accuracy: 0.7308
# Epoch 32/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.6802 - accuracy: 0.7070 - val_loss: 0.5169 - val_accuracy: 0.7212
# Epoch 33/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.6455 - accuracy: 0.7264 - val_loss: 0.5120 - val_accuracy: 0.7404
# Epoch 34/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.6237 - accuracy: 0.7094 - val_loss: 0.5048 - val_accuracy: 0.7404
# Epoch 35/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.8052 - accuracy: 0.7046 - val_loss: 0.4940 - val_accuracy: 0.7500
# Epoch 36/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.6429 - accuracy: 0.7579 - val_loss: 0.5004 - val_accuracy: 0.7500
# Epoch 37/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.6167 - accuracy: 0.7506 - val_loss: 0.5919 - val_accuracy: 0.7500
# Epoch 38/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5664 - accuracy: 0.7264 - val_loss: 0.5843 - val_accuracy: 0.7500
# Epoch 39/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.6898 - accuracy: 0.7046 - val_loss: 0.5769 - val_accuracy: 0.7500
# Epoch 40/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5470 - accuracy: 0.7700 - val_loss: 0.5701 - val_accuracy: 0.7500
# Epoch 41/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5970 - accuracy: 0.7724 - val_loss: 0.5629 - val_accuracy: 0.7500
# Epoch 42/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5005 - accuracy: 0.7724 - val_loss: 0.5545 - val_accuracy: 0.7404
# Epoch 43/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5370 - accuracy: 0.7845 - val_loss: 0.5464 - val_accuracy: 0.7404
# Epoch 44/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5166 - accuracy: 0.7869 - val_loss: 0.5393 - val_accuracy: 0.7404
# Epoch 45/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4962 - accuracy: 0.8087 - val_loss: 0.4231 - val_accuracy: 0.7404
# Epoch 46/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4654 - accuracy: 0.7869 - val_loss: 0.4080 - val_accuracy: 0.7500
# Epoch 47/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4613 - accuracy: 0.7990 - val_loss: 0.3921 - val_accuracy: 0.7885
# Epoch 48/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5218 - accuracy: 0.7942 - val_loss: 0.3844 - val_accuracy: 0.7788
# Epoch 49/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5167 - accuracy: 0.7772 - val_loss: 0.3735 - val_accuracy: 0.7981
# Epoch 50/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4271 - accuracy: 0.8015 - val_loss: 0.3651 - val_accuracy: 0.8462
# Epoch 51/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4777 - accuracy: 0.7990 - val_loss: 0.3524 - val_accuracy: 0.8558
# Epoch 52/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4463 - accuracy: 0.7942 - val_loss: 0.3424 - val_accuracy: 0.8654
# Epoch 53/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3704 - accuracy: 0.8257 - val_loss: 0.3319 - val_accuracy: 0.8654
# Epoch 54/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3211 - accuracy: 0.8523 - val_loss: 0.3220 - val_accuracy: 0.8846
# Epoch 55/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3349 - accuracy: 0.8354 - val_loss: 0.3108 - val_accuracy: 0.8750
# Epoch 56/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3404 - accuracy: 0.8378 - val_loss: 0.3002 - val_accuracy: 0.8942
# Epoch 57/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3617 - accuracy: 0.8475 - val_loss: 0.2889 - val_accuracy: 0.8942
# Epoch 58/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3863 - accuracy: 0.8741 - val_loss: 0.2791 - val_accuracy: 0.8942
# Epoch 59/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3850 - accuracy: 0.8620 - val_loss: 0.2721 - val_accuracy: 0.9135
# Epoch 60/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2731 - accuracy: 0.8862 - val_loss: 0.2619 - val_accuracy: 0.9135
# Epoch 61/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3536 - accuracy: 0.8838 - val_loss: 0.2498 - val_accuracy: 0.9135
# Epoch 62/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2399 - accuracy: 0.8983 - val_loss: 0.2415 - val_accuracy: 0.9038
# Epoch 63/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2825 - accuracy: 0.8789 - val_loss: 0.2345 - val_accuracy: 0.9038
# Epoch 64/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2860 - accuracy: 0.8886 - val_loss: 0.2278 - val_accuracy: 0.9135
# Epoch 65/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2435 - accuracy: 0.9080 - val_loss: 0.2198 - val_accuracy: 0.9231
# Epoch 66/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.8910 - val_loss: 0.2110 - val_accuracy: 0.9423
# Epoch 67/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2205 - accuracy: 0.9177 - val_loss: 0.2045 - val_accuracy: 0.9423
# Epoch 68/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2326 - accuracy: 0.9031 - val_loss: 0.1971 - val_accuracy: 0.9519
# Epoch 69/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2167 - accuracy: 0.9225 - val_loss: 0.1912 - val_accuracy: 0.9519
# Epoch 70/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2090 - accuracy: 0.9322 - val_loss: 0.1861 - val_accuracy: 0.9519
# Epoch 71/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1920 - accuracy: 0.9516 - val_loss: 0.1806 - val_accuracy: 0.9519
# Epoch 72/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2390 - accuracy: 0.9298 - val_loss: 0.1759 - val_accuracy: 0.9519
# Epoch 73/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1857 - accuracy: 0.9346 - val_loss: 0.1716 - val_accuracy: 0.9519
# Epoch 74/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2232 - accuracy: 0.9322 - val_loss: 0.1665 - val_accuracy: 0.9519
# Epoch 75/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 0.9370 - val_loss: 0.1628 - val_accuracy: 0.9519
# Epoch 76/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2094 - accuracy: 0.9395 - val_loss: 0.1614 - val_accuracy: 0.9423
# Epoch 77/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1421 - accuracy: 0.9467 - val_loss: 0.1474 - val_accuracy: 0.9519
# Epoch 78/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1663 - accuracy: 0.9419 - val_loss: 0.1510 - val_accuracy: 0.9519
# Epoch 79/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1183 - accuracy: 0.9516 - val_loss: 0.1491 - val_accuracy: 0.9712
# Epoch 80/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1175 - accuracy: 0.9492 - val_loss: 0.2458 - val_accuracy: 0.9519
# Epoch 81/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1089 - accuracy: 0.9516 - val_loss: 0.1519 - val_accuracy: 0.9519
# Epoch 82/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1006 - accuracy: 0.9588 - val_loss: 0.1310 - val_accuracy: 0.9519
# Epoch 83/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1079 - accuracy: 0.9564 - val_loss: 0.2347 - val_accuracy: 0.9519
# Epoch 84/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0984 - accuracy: 0.9637 - val_loss: 0.2315 - val_accuracy: 0.9519
# Epoch 85/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0990 - accuracy: 0.9588 - val_loss: 0.2296 - val_accuracy: 0.9615
# Epoch 86/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1429 - accuracy: 0.9467 - val_loss: 0.2264 - val_accuracy: 0.9615
# Epoch 87/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0943 - accuracy: 0.9588 - val_loss: 0.2231 - val_accuracy: 0.9615
# Epoch 88/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1251 - accuracy: 0.9613 - val_loss: 0.2208 - val_accuracy: 0.9615
# Epoch 89/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0885 - accuracy: 0.9758 - val_loss: 0.2184 - val_accuracy: 0.9615
# Epoch 90/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0781 - accuracy: 0.9734 - val_loss: 0.2155 - val_accuracy: 0.9712
# Epoch 91/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0839 - accuracy: 0.9613 - val_loss: 0.2141 - val_accuracy: 0.9712
# Epoch 92/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0730 - accuracy: 0.9685 - val_loss: 0.2117 - val_accuracy: 0.9712
# Epoch 93/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0786 - accuracy: 0.9709 - val_loss: 0.2127 - val_accuracy: 0.9712
# Epoch 94/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0727 - accuracy: 0.9709 - val_loss: 0.2125 - val_accuracy: 0.9712
# Epoch 95/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0747 - accuracy: 0.9782 - val_loss: 0.2136 - val_accuracy: 0.9712
# Epoch 96/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0715 - accuracy: 0.9758 - val_loss: 0.2138 - val_accuracy: 0.9712
# Epoch 97/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1077 - accuracy: 0.9758 - val_loss: 0.2138 - val_accuracy: 0.9712
# Epoch 98/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0554 - accuracy: 0.9709 - val_loss: 0.2135 - val_accuracy: 0.9712
# Epoch 99/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0454 - accuracy: 0.9927 - val_loss: 0.2142 - val_accuracy: 0.9712
# Epoch 100/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0695 - accuracy: 0.9734 - val_loss: 0.2109 - val_accuracy: 0.9712
# Train: 0.998, Valid: 0.971

# %%
plt.figure(figsize=[8,5])
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.legend()
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves Epoch 100, Batch Size 10', fontsize=16)
plt.show()

# %%
def init_model():
    # define model
    model = Sequential()
    model.add(Dense(6, input_dim=13, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    model.compile(optimizer ='adam',
    metrics=['accuracy'],
    loss = 'binary_crossentropy')
    return model

# init model
model = init_model()

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=150)

# model checkpoint
mc = ModelCheckpoint('models/best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# fitting model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=250, verbose=0, batch_size=6, 
                    callbacks = [es, mc])
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.26923, saving model to models/best_model.h5
#
# Epoch 2: val_accuracy did not improve from 0.26923
#
# Epoch 3: val_accuracy did not improve from 0.26923
#
# Epoch 4: val_accuracy improved from 0.26923 to 0.28846, saving model to models/best_model.h5
#
# Epoch 5: val_accuracy improved from 0.28846 to 0.34615, saving model to models/best_model.h5
#
# Epoch 6: val_accuracy improved from 0.34615 to 0.38462, saving model to models/best_model.h5
#
# Epoch 7: val_accuracy improved from 0.38462 to 0.50000, saving model to models/best_model.h5
#
# Epoch 8: val_accuracy did not improve from 0.50000
#
# Epoch 9: val_accuracy improved from 0.50000 to 0.60577, saving model to models/best_model.h5
#
# Epoch 10: val_accuracy did not improve from 0.60577
#
# Epoch 11: val_accuracy improved from 0.60577 to 0.63462, saving model to models/best_model.h5
#
# Epoch 12: val_accuracy improved from 0.63462 to 0.64423, saving model to models/best_model.h5
#
# Epoch 13: val_accuracy improved from 0.64423 to 0.67308, saving model to models/best_model.h5
#
# Epoch 14: val_accuracy improved from 0.67308 to 0.68269, saving model to models/best_model.h5
#
# Epoch 15: val_accuracy improved from 0.68269 to 0.71154, saving model to models/best_model.h5
#
# Epoch 16: val_accuracy improved from 0.71154 to 0.72115, saving model to models/best_model.h5
#
# Epoch 17: val_accuracy improved from 0.72115 to 0.75000, saving model to models/best_model.h5
#
# Epoch 18: val_accuracy did not improve from 0.75000
#
# Epoch 19: val_accuracy did not improve from 0.75000
#
# Epoch 20: val_accuracy did not improve from 0.75000
#
# Epoch 21: val_accuracy improved from 0.75000 to 0.75962, saving model to models/best_model.h5
#
# Epoch 22: val_accuracy did not improve from 0.75962
#
# Epoch 23: val_accuracy did not improve from 0.75962
#
# Epoch 24: val_accuracy improved from 0.75962 to 0.79808, saving model to models/best_model.h5
#
# Epoch 25: val_accuracy improved from 0.79808 to 0.80769, saving model to models/best_model.h5
#
# Epoch 26: val_accuracy did not improve from 0.80769
#
# Epoch 27: val_accuracy did not improve from 0.80769
#
# Epoch 28: val_accuracy did not improve from 0.80769
#
# Epoch 29: val_accuracy did not improve from 0.80769
#
# Epoch 30: val_accuracy did not improve from 0.80769
#
# Epoch 31: val_accuracy did not improve from 0.80769
#
# Epoch 32: val_accuracy did not improve from 0.80769
#
# Epoch 33: val_accuracy did not improve from 0.80769
#
# Epoch 34: val_accuracy did not improve from 0.80769
#
# Epoch 35: val_accuracy did not improve from 0.80769
#
# Epoch 36: val_accuracy did not improve from 0.80769
#
# Epoch 37: val_accuracy did not improve from 0.80769
#
# Epoch 38: val_accuracy did not improve from 0.80769
#
# Epoch 39: val_accuracy did not improve from 0.80769
#
# Epoch 40: val_accuracy did not improve from 0.80769
#
# Epoch 41: val_accuracy did not improve from 0.80769
#
# Epoch 42: val_accuracy did not improve from 0.80769
#
# Epoch 43: val_accuracy did not improve from 0.80769
#
# Epoch 44: val_accuracy improved from 0.80769 to 0.81731, saving model to models/best_model.h5
#
# Epoch 45: val_accuracy did not improve from 0.81731
#
# Epoch 46: val_accuracy improved from 0.81731 to 0.85577, saving model to models/best_model.h5
#
# Epoch 47: val_accuracy improved from 0.85577 to 0.86538, saving model to models/best_model.h5
#
# Epoch 48: val_accuracy did not improve from 0.86538
#
# Epoch 49: val_accuracy improved from 0.86538 to 0.87500, saving model to models/best_model.h5
#
# Epoch 50: val_accuracy improved from 0.87500 to 0.88462, saving model to models/best_model.h5
#
# Epoch 51: val_accuracy did not improve from 0.88462
#
# Epoch 52: val_accuracy improved from 0.88462 to 0.89423, saving model to models/best_model.h5
#
# Epoch 53: val_accuracy did not improve from 0.89423
#
# Epoch 54: val_accuracy did not improve from 0.89423
#
# Epoch 55: val_accuracy improved from 0.89423 to 0.90385, saving model to models/best_model.h5
#
# Epoch 56: val_accuracy improved from 0.90385 to 0.91346, saving model to models/best_model.h5
#
# Epoch 57: val_accuracy improved from 0.91346 to 0.92308, saving model to models/best_model.h5
#
# Epoch 58: val_accuracy improved from 0.92308 to 0.93269, saving model to models/best_model.h5
#
# Epoch 59: val_accuracy did not improve from 0.93269
#
# Epoch 60: val_accuracy did not improve from 0.93269
#
# Epoch 61: val_accuracy did not improve from 0.93269
#
# Epoch 62: val_accuracy did not improve from 0.93269
#
# Epoch 63: val_accuracy did not improve from 0.93269
#
# Epoch 64: val_accuracy did not improve from 0.93269
#
# Epoch 65: val_accuracy did not improve from 0.93269
#
# Epoch 66: val_accuracy did not improve from 0.93269
#
# Epoch 67: val_accuracy did not improve from 0.93269
#
# Epoch 68: val_accuracy did not improve from 0.93269
#
# Epoch 69: val_accuracy improved from 0.93269 to 0.94231, saving model to models/best_model.h5
#
# Epoch 70: val_accuracy did not improve from 0.94231
#
# Epoch 71: val_accuracy did not improve from 0.94231
#
# Epoch 72: val_accuracy did not improve from 0.94231
#
# Epoch 73: val_accuracy did not improve from 0.94231
#
# Epoch 74: val_accuracy did not improve from 0.94231
#
# Epoch 75: val_accuracy did not improve from 0.94231
#
# Epoch 76: val_accuracy improved from 0.94231 to 0.95192, saving model to models/best_model.h5
#
# Epoch 77: val_accuracy did not improve from 0.95192
#
# Epoch 78: val_accuracy did not improve from 0.95192
#
# Epoch 79: val_accuracy did not improve from 0.95192
#
# Epoch 80: val_accuracy did not improve from 0.95192
#
# Epoch 81: val_accuracy did not improve from 0.95192
#
# Epoch 82: val_accuracy did not improve from 0.95192
#
# Epoch 83: val_accuracy did not improve from 0.95192
#
# Epoch 84: val_accuracy did not improve from 0.95192
#
# Epoch 85: val_accuracy did not improve from 0.95192
#
# Epoch 86: val_accuracy did not improve from 0.95192
#
# Epoch 87: val_accuracy did not improve from 0.95192
#
# Epoch 88: val_accuracy did not improve from 0.95192
#
# Epoch 89: val_accuracy did not improve from 0.95192
#
# Epoch 90: val_accuracy did not improve from 0.95192
#
# Epoch 91: val_accuracy did not improve from 0.95192
#
# Epoch 92: val_accuracy did not improve from 0.95192
#
# Epoch 93: val_accuracy did not improve from 0.95192
#
# Epoch 94: val_accuracy did not improve from 0.95192
#
# Epoch 95: val_accuracy did not improve from 0.95192
#
# Epoch 96: val_accuracy did not improve from 0.95192
#
# Epoch 97: val_accuracy did not improve from 0.95192
#
# Epoch 98: val_accuracy did not improve from 0.95192
#
# Epoch 99: val_accuracy did not improve from 0.95192
#
# Epoch 100: val_accuracy did not improve from 0.95192
#
# Epoch 101: val_accuracy did not improve from 0.95192
#
# Epoch 102: val_accuracy did not improve from 0.95192
#
# Epoch 103: val_accuracy did not improve from 0.95192
#
# Epoch 104: val_accuracy did not improve from 0.95192
#
# Epoch 105: val_accuracy did not improve from 0.95192
#
# Epoch 106: val_accuracy did not improve from 0.95192
#
# Epoch 107: val_accuracy did not improve from 0.95192
#
# Epoch 108: val_accuracy did not improve from 0.95192
#
# Epoch 109: val_accuracy did not improve from 0.95192
#
# Epoch 110: val_accuracy did not improve from 0.95192
#
# Epoch 111: val_accuracy did not improve from 0.95192
#
# Epoch 112: val_accuracy did not improve from 0.95192
#
# Epoch 113: val_accuracy did not improve from 0.95192
#
# Epoch 114: val_accuracy did not improve from 0.95192
#
# Epoch 115: val_accuracy did not improve from 0.95192
#
# Epoch 116: val_accuracy did not improve from 0.95192
#
# Epoch 117: val_accuracy did not improve from 0.95192
#
# Epoch 118: val_accuracy did not improve from 0.95192
#
# Epoch 119: val_accuracy did not improve from 0.95192
#
# Epoch 120: val_accuracy did not improve from 0.95192
#
# Epoch 121: val_accuracy did not improve from 0.95192
#
# Epoch 122: val_accuracy did not improve from 0.95192
#
# Epoch 123: val_accuracy did not improve from 0.95192
#
# Epoch 124: val_accuracy did not improve from 0.95192
#
# Epoch 125: val_accuracy did not improve from 0.95192
#
# Epoch 126: val_accuracy did not improve from 0.95192
#
# Epoch 127: val_accuracy did not improve from 0.95192
#
# Epoch 128: val_accuracy improved from 0.95192 to 0.96154, saving model to models/best_model.h5
#
# Epoch 129: val_accuracy did not improve from 0.96154
#
# Epoch 130: val_accuracy did not improve from 0.96154
#
# Epoch 131: val_accuracy did not improve from 0.96154
#
# Epoch 132: val_accuracy did not improve from 0.96154
# Epoch 133: val_accuracy did not improve from 0.96154
#
# Epoch 134: val_accuracy did not improve from 0.96154
#
# Epoch 135: val_accuracy did not improve from 0.96154
#
# Epoch 136: val_accuracy did not improve from 0.96154
#
# Epoch 137: val_accuracy did not improve from 0.96154
#
# Epoch 138: val_accuracy did not improve from 0.96154
#
# Epoch 139: val_accuracy did not improve from 0.96154
#
# Epoch 140: val_accuracy did not improve from 0.96154
#
# Epoch 141: val_accuracy did not improve from 0.96154
#
# Epoch 142: val_accuracy did not improve from 0.96154
#
# Epoch 143: val_accuracy did not improve from 0.96154
#
# Epoch 144: val_accuracy did not improve from 0.96154
#
# Epoch 145: val_accuracy did not improve from 0.96154
#
# Epoch 146: val_accuracy did not improve from 0.96154
#
# Epoch 147: val_accuracy did not improve from 0.96154
#
# Epoch 148: val_accuracy did not improve from 0.96154
#
# Epoch 149: val_accuracy did not improve from 0.96154
#
# Epoch 150: val_accuracy did not improve from 0.96154
#
# Epoch 151: val_accuracy did not improve from 0.96154
#
# Epoch 152: val_accuracy did not improve from 0.96154
#
# Epoch 153: val_accuracy did not improve from 0.96154
#
# Epoch 154: val_accuracy did not improve from 0.96154
#
# Epoch 155: val_accuracy did not improve from 0.96154
#
# Epoch 156: val_accuracy did not improve from 0.96154
#
# Epoch 157: val_accuracy did not improve from 0.96154
#
# Epoch 158: val_accuracy did not improve from 0.96154
#
# Epoch 159: val_accuracy did not improve from 0.96154
#
# Epoch 160: val_accuracy did not improve from 0.96154
#
# Epoch 161: val_accuracy did not improve from 0.96154
#
# Epoch 162: val_accuracy did not improve from 0.96154
#
# Epoch 163: val_accuracy did not improve from 0.96154
#
# Epoch 164: val_accuracy did not improve from 0.96154
#
# Epoch 165: val_accuracy did not improve from 0.96154
#
# Epoch 166: val_accuracy did not improve from 0.96154
#
# Epoch 167: val_accuracy did not improve from 0.96154
#
# Epoch 168: val_accuracy did not improve from 0.96154
#
# Epoch 169: val_accuracy did not improve from 0.96154
#
# Epoch 170: val_accuracy did not improve from 0.96154
#
# Epoch 171: val_accuracy did not improve from 0.96154
#
# Epoch 172: val_accuracy did not improve from 0.96154
#
# Epoch 173: val_accuracy did not improve from 0.96154
#
# Epoch 174: val_accuracy did not improve from 0.96154
#
# Epoch 175: val_accuracy did not improve from 0.96154
#
# Epoch 176: val_accuracy did not improve from 0.96154
#
# Epoch 177: val_accuracy did not improve from 0.96154
#
# Epoch 178: val_accuracy improved from 0.96154 to 0.97115, saving model to models/best_model.h5
#
# Epoch 179: val_accuracy did not improve from 0.97115
#
# Epoch 180: val_accuracy did not improve from 0.97115
#
# Epoch 181: val_accuracy did not improve from 0.97115
#
# Epoch 182: val_accuracy did not improve from 0.97115
#
# Epoch 183: val_accuracy did not improve from 0.97115
#
# Epoch 184: val_accuracy did not improve from 0.97115
#
# Epoch 185: val_accuracy did not improve from 0.97115
#
# Epoch 186: val_accuracy did not improve from 0.97115
#
# Epoch 187: val_accuracy did not improve from 0.97115
#
# Epoch 188: val_accuracy did not improve from 0.97115
#
# Epoch 189: val_accuracy did not improve from 0.97115
#
# Epoch 190: val_accuracy did not improve from 0.97115
#
# Epoch 191: val_accuracy did not improve from 0.97115
#
# Epoch 192: val_accuracy did not improve from 0.97115
#
# Epoch 193: val_accuracy did not improve from 0.97115
#
# Epoch 194: val_accuracy did not improve from 0.97115
#
# Epoch 195: val_accuracy did not improve from 0.97115
#
# Epoch 196: val_accuracy did not improve from 0.97115
#
# Epoch 197: val_accuracy did not improve from 0.97115
#
# Epoch 198: val_accuracy did not improve from 0.97115
#
# Epoch 199: val_accuracy did not improve from 0.97115
#
# Epoch 200: val_accuracy did not improve from 0.97115
#
# Epoch 201: val_accuracy did not improve from 0.97115
#
# Epoch 202: val_accuracy did not improve from 0.97115
#
# Epoch 203: val_accuracy did not improve from 0.97115
#
# Epoch 204: val_accuracy did not improve from 0.97115
#
# Epoch 205: val_accuracy did not improve from 0.97115
#
# Epoch 206: val_accuracy did not improve from 0.97115
#
# Epoch 207: val_accuracy did not improve from 0.97115
#
# Epoch 208: val_accuracy did not improve from 0.97115
#
# Epoch 209: val_accuracy did not improve from 0.97115
#
# Epoch 210: val_accuracy did not improve from 0.97115
#
# Epoch 211: val_accuracy did not improve from 0.97115
#
# Epoch 212: val_accuracy did not improve from 0.97115
#
# Epoch 213: val_accuracy did not improve from 0.97115
#
# Epoch 214: val_accuracy did not improve from 0.97115
#
# Epoch 215: val_accuracy did not improve from 0.97115
#
# Epoch 216: val_accuracy did not improve from 0.97115
#
# Epoch 217: val_accuracy did not improve from 0.97115
#
# Epoch 218: val_accuracy did not improve from 0.97115
#
# Epoch 219: val_accuracy did not improve from 0.97115
#
# Epoch 220: val_accuracy did not improve from 0.97115
#
# Epoch 221: val_accuracy did not improve from 0.97115
#
# Epoch 222: val_accuracy did not improve from 0.97115
#
# Epoch 223: val_accuracy did not improve from 0.97115
#
# Epoch 224: val_accuracy did not improve from 0.97115
#
# Epoch 225: val_accuracy did not improve from 0.97115
#
# Epoch 226: val_accuracy did not improve from 0.97115
#
# Epoch 227: val_accuracy did not improve from 0.97115
#
# Epoch 228: val_accuracy did not improve from 0.97115
#
# Epoch 229: val_accuracy did not improve from 0.97115
#
# Epoch 230: val_accuracy did not improve from 0.97115
#
# Epoch 231: val_accuracy did not improve from 0.97115
#
# Epoch 232: val_accuracy did not improve from 0.97115
#
# Epoch 233: val_accuracy did not improve from 0.97115
#
# Epoch 234: val_accuracy did not improve from 0.97115
#
# Epoch 235: val_accuracy did not improve from 0.97115
#
# Epoch 236: val_accuracy did not improve from 0.97115
#
# Epoch 237: val_accuracy did not improve from 0.97115
#
# Epoch 238: val_accuracy did not improve from 0.97115
#
# Epoch 239: val_accuracy did not improve from 0.97115
# Epoch 239: early stopping

# %%
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='valid')
plt.legend()
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Loss Curves', fontsize=16)
plt.show()

# %%
plt.figure(figsize=[8,5])
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.legend()
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves', fontsize=16)
plt.show()

# %% [markdown]
# ## What if... we had different or better data?

# %%
# import geopandas as gpd
# import folium

# # Replace 'your_shapefile.shp' with the path to your shapefile
# gdf = gpd.read_file('./data/Wildfires_1878_2019_Polygon_Data/Shapefile/US_Wildfires_1878_2019.shp')
# gdf = gdf.to_crs({'proj':'longlat', 'ellps':'WGS84', 'datum':'WGS84'})
# gdf['centroid'] = gpd.GeoSeries(gdf["geometry"]).centroid
# gdf.to_pickle('geo_dataframe_forest_fires.pkl')

# my_map = folium.Map(tiles = 'cartodbdark_matter')
# for _, r in test_df.iterrows():
#     sim_geo = gpd.GeoSeries(r["geometry"]).simplify(tolerance=0.001)
#     geo_j = sim_geo.to_json()
#     geo_j = folium.GeoJson(data = geo_j, style_function=lambda x: {'fillColor': 'orange',
#                                                                    'color': 'yellow',
#                                                                    'weight': 1,
#                                                                    'fillOpacity': 1})
#     #folium.Popup(r["FireCause"]).add_to(geo_j)
#     geo_j.add_to(my_map)
# #my_map.save("forest_fires.html")
# my_map

# %%
#test_df = pd.read_pickle('data/geo_dataframe_forest_fires.pkl')
#print(test_df.info())
test_df.head()
# Out:
#   FireName               FireCode  FireYear    IgntDate ContrlDate ContnDate  \
# 0   414008  AK6535415457219840611      1984  1984-06-11        NaN       NaN
# 1   414012  AK6621715235619840618      1984  1984-06-18        NaN       NaN
# 2   414057  AK6495716269319840702      1984  1984-07-02        NaN       NaN
# 3   414060  AK6379515502919840623      1984  1984-06-23        NaN       NaN
# 4    ABERT  OR4258812018119840809      1984  1984-08-09        NaN       NaN
#
#          Acres     Hectares                             DataSrc  \
# 0  3169.156439  1282.513243  Monitoring Trends in Burn Severity
# 1  1964.386646   794.959774  Monitoring Trends in Burn Severity
# 2  1688.849283   683.453661  Monitoring Trends in Burn Severity
# 3  1399.226822   566.247506  Monitoring Trends in Burn Severity
# 4  7945.460289  3215.416542  Monitoring Trends in Burn Severity
#
#                                            DataNotes           FireCause  \
# 0  First Tier Wildfires, polygon with largest acr...  No cause indicated
# 1  First Tier Wildfires, polygon with largest acr...  No cause indicated
# 2  First Tier Wildfires, polygon with largest acr...  No cause indicated
# 3  First Tier Wildfires, polygon with largest acr...  No cause indicated
# 4  First Tier Wildfires, polygon with largest acr...  No cause indicated
#
#                                              FoundIn  \
# 0  Alternate Fire Sources: Monitoring Trends in B...
# 1  Alternate Fire Sources: Monitoring Trends in B...
# 2  Alternate Fire Sources: Monitoring Trends in B...
# 3  Alternate Fire Sources: Monitoring Trends in B...
# 4  Alternate Fire Sources: BLM National Fire Peri...
#
#                                     FndNames  \
# 0               Alternate Fire Names: 414008
# 1               Alternate Fire Names: 414012
# 2               Alternate Fire Names: 414057
# 3               Alternate Fire Names: 414060
# 4  Alternate Fire Names: Abert, Abert, ABERT
#
#                                             FndCodes  \
# 0        Alternate Fire Codes: AK6535415457219840611
# 1        Alternate Fire Codes: AK6621715235619840618
# 2        Alternate Fire Codes: AK6495716269319840702
# 3        Alternate Fire Codes: AK6379515502919840623
# 4  Alternate Fire Codes: M053, M053, OR4258812018...
#
#                                             FndDates  FireQual    Shape_Leng  \
# 0  Alternate Ignition, Controlled, and Contained ...         1  22876.846278
# 1  Alternate Ignition, Controlled, and Contained ...         1  17290.576444
# 2  Alternate Ignition, Controlled, and Contained ...         1  11226.497241
# 3  Alternate Ignition, Controlled, and Contained ...         1  18047.888216
# 4  Alternate Ignition, Controlled, and Contained ...         1  73017.681929
#
#      Shape_Area                                           geometry  \
# 0  1.282513e+07  POLYGON ((-154.61761 65.37700, -154.61268 65.3...
# 1  7.949598e+06  POLYGON ((-152.35902 66.23226, -152.34487 66.2...
# 2  6.834537e+06  POLYGON ((-162.68840 64.96873, -162.68733 64.9...
# 3  5.662475e+06  POLYGON ((-155.01554 63.81320, -155.01398 63.8...
# 4  3.215417e+07  POLYGON ((-120.12878 42.67433, -120.12909 42.6...
#
#                       centroid
# 0  POINT (-154.57250 65.35357)
# 1  POINT (-152.35598 66.21713)
# 2  POINT (-162.69301 64.95674)
# 3  POINT (-155.02878 63.79490)
# 4  POINT (-120.18143 42.58840)

# %%
IFrame(src="images/forest_fires.html", width=900, height=800)
# Out:
#         <iframe
#             width="900"
#             height="800"
#             src="images/forest_fires.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#https://pdf.sciencedirectassets.com/271100/1-s2.0-S0379711219X00028/1-s2.0-S0379711218303941/am.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEFkaCXVzLWVhc3QtMSJGMEQCIB6%2BrP729s6pOcd3RO8MOnfurh3JEkz3x5YghLvpPrNRAiBaWbgpz6TYtOMzEZKdaczL56O4QENCk5HZO1k2s7LOEyq8BQix%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAUaDDA1OTAwMzU0Njg2NSIMt816wIlFIr8aw6Y%2FKpAFha3vg1FILlX33M9Yn%2F%2F8Ln4q2wttgJL8A0mUR52lEptZVBRBtDKGZ6pJMEC0NymWt7hlmD4PkxD9uJszMq%2FolInsEQkMDhZcx80cUagpZYH0UR33nDrfmAyjASm%2FR28LUmIdQfkrp0JEIAVdSMxHg7PLzT4fXzYBDekJVyW1teoA4OaBoruJb%2BkGrN6iqtItrvIqbxN86HjuYbsLiKcZTQMLwUdXMK9PzsSuK7ckpuycoMu44vSPDvoNU%2BFGrPIfUAnVNqpmSBUbuOHvl5ULkiuKw8C9LBIitO%2BZcTCizvmAiM%2B6lsWKpLlBx%2BDvNrqu5Tj7mmN75E5o238XwigPV%2BDlC2Sv%2FGZgaVeDsqqawshXT2kE%2B1zrzmtVgA9J495A6Yu%2FMQZzQYgEwHB63bFMNnVonz1YOCUjKXDCXPsSfEY35KRhb04AMWoFjli3wsGlpdwTxqSqEyKhPRsS%2BVx5e%2FXvcszOgQeW4g%2FWRi2p5sY3C7LFTLFXZ%2BS5g8u0%2F4VpGJKkd6NMiAVIBKC13HXwWc%2F0hR%2BZCYCpRIqxCaLuVrcHeRIx90Zv4sdM5G4J%2FzQgnvMqOTmKcORn0v7%2BCknqN7re3cTswxh3%2FkA07LvG%2BYnkBX2mo7bqSe2IFwohM9cRdAvytsUR5Qo7IwQInCMlCN5AseMNbEhZ4os0zMHDaCHUvhaos%2FjDtG4ll0ewMgT7GQKZ5xMIetUSxB9G2C8DkaV4rvolaCebu1QLGsiaf9Sn0BT8OHqixlWpRt3qBSb%2FXengCYwKLATRoefvUfRrM9Ddfr5FRUExuca3yQVRtKz6ibnNZbUbe3bufyV%2FvUDI4ZvaxuWh13zlt1b5LL7bMYqLyyzi4ed2MdJM0emhanQwkd6UqwY6sgGboIm0vi1pPjXxvMG4nfUJoanyhSJ4KZqMOPqmaDr2TOerDPkMmnvVxUpZ1zEPPpg3ew3BhqxDz4%2Be6CDg%2FOLIUOk5njvwEpx0wAM0V0XgdGKxa57JQuk85EYUp9tLZ4%2FmfkYo84onIedu4ig%2BKOZasOPjH%2B54VFx6ekJOw1GHEDh20ZG3XJQ0ZEjTn7ilqhjvpCL1KusuN6y%2B81Pxwjj7WL3GG6PYDYm%2FLdnpwoFcRlMw&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231128T003309Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTYWWV37SQY%2F20231128%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=c33d3df67240330cb588a4eb76b655ecd01191cdb98cd24c5f49c7a922309983&hash=bf059bd61fc8778f809a598de2aada60e4a3e75e672853757544641ac0ed95b2&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S0379711218303941&tid=pdf-9dc187da-f80b-4720-8f62-1882dd8caf87&sid=5afc32371e344648f128f916f88a52edc0d7gxrqa&type=client
#https://towardsdatascience.com/creating-an-interactive-map-of-wildfire-data-using-folium-in-python-7d6373b6334a
#https://www.sciencebase.gov/catalog/item/5ee13de982ce3bd58d7be7e7
#https://palkovic.org/wp-content/uploads/2020/12/USGS_wildfires.html

# %% [markdown]
# # Want to learn more?
#
# * What is Artificial Intelligence? https://rb.gy/tm1xbd
# * Top 10 Machine Learning Algorithms for Beginners https://rb.gy/cosidk
# * The Hidden Dangers of Data Science https://rb.gy/7aiwan
