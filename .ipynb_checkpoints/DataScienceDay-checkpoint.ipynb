# %% [markdown]
# <img align = "center" src= "images/mu_logo.png" width="300"/>
#
# ---
#
# <h1><b>Data Science Day</b></h1>
# <h3>Friday, December 1, 2023 </h3>
#
# ---
#
# <h2> <b> Presenters:</b> </h2>
# <h3> <b> Andrew Casanova, </b> Senior Data Scientist, Black Cape IO </h3>
# <h3> <b> Lindsey Tagg, </b> Senior Data Scientist, Deloitte LLP </h3>
#
# ---
# <center>
# <h2> Itinerary: </h2>
#
# <h3> I. What is Data Science? (Andrew Casanova) </h3>
# <h3> II. Detecting Fraud, Waste & Abuse. (Lindsey Tagg) </h3>
# <h3> III. Data Science Models in Action. (Andrew & Lindsey) </h3>
# </center>

# %% [markdown]
# # I. What is Data Science?
# <div>
#     <img src= "images/what_is_data_science.png" width="800"/>
#     <img src= "images/ai_venn_diagram.png" width="800"/>
# </div>

# %% [markdown]
# ## What's the difference?
# <div>
# <img src="images/whats_the_difference.png" width="800"/>
# </div>

# %% [markdown]
# ## The Workflow
# <div>
# <img src="images/the_workflow.png" width="700"/>
# </div>

# %% [markdown]
# ## Popular Methods
# ### Question: What are some technologies you use every day that may use these methods?
#
# <div>
# <img src="images/popular_methods.png" width="900"/>
# </div>

# %% [markdown]
# ## How does it work?
#
# <div>
#     <center> <h3> Supervised Learning </h3></center>
#     <img src="images/supervised_learning.png" width="900"/>
#     <center><h3> Unsupervised Learning </h3></center>
#     <img src="images/unsupervised_learning.png" width = "900"/>
# </div>

# %% [markdown]
# ## Using Data Science Has Consequences
#
# <div>
# <img src="images/consequences.png" width="300"/>
# </div>
#
# * ### Not understanding the problem
# * ### Measuring Error
# * ### Converting People into Numbers
# * ### Model Interpretability
# * ### Causal Modelling
# * ### Bias & Ethics

# %% [markdown]
# ## Why Data Science is Awesome!
#
# * ### Have a HUGE impact
# * ### Growing Demand
# * ### Data Science Salaries
# * ### An Ever-Evolving Field
# * ### Diverse Career Growth Options
#
# <div>
# <img src="images/data_science_is_awesome.png" width="900"/>
# </div>

# %% [markdown]
# ## What Makes a Great Data Scientist?
#
# * ### Care about the work
# * ### Be motivated and life-long learners
# * ### Enjoy problem-solving
# * ### Are effective communicators
#
# <div>
# <img src="images/be_greater_than_avg.png" width="600"/>
# </div>

# %% [markdown]
# # II. Detecting Fraud, Waste & Abuse
#
#
# <div>
# <img src="images/fraud_triangle.png" width="300"/>
# </div>

# %% [markdown]
# ## What is Fraud, Waste and Abuse?
#
# * **Fraud:** An intentional misrepresentation or lie in order to elicit, prevent or avoid an action or response.
#
# * **Waste:** Carelessness and bloat around programs or procedures that may cause harm to a program or taxpayers.
#
# * **Abuse:** Manipulating program/rules in a way that is not true to the spirit of the program to elicit a response or funds.
#
# ## Here are a few examples:
#
# * Intentionally or uninentionally distributing additional funds to vendors or people through lack of oversight.
#
# * Intentionally manipulating or leveraging program loopholes to receive funds, benefits and more.
#
# * Someone saying that they graduated from a degree program that they never attended, or requesting benefits that they're not eligible for.

# %% [markdown]
# ## Be the Fraudster
#
#
# <html> <h3>
#     Putting the 'Scientist' in Data Scientist-- What is the Scientific Method?
# </h3></html>
#
# 1. Question
# 2. Research
# 3. Hypothesis
# 4. Experiment
# 5. Analyze Data
# 6. Conclusion
# 7. Communicate
#
#
# ## How and when do we apply the scientific method in practice?
#
# <html> <h3>
#     Put yourself in the shoes of a Fraudster. A Fraudster's goal would be to:
# </h3> </html>
#
# 1. Avoid Detection
# 2. Infiltrate through hacking, identity theft, identity simulation or misrepresentation.
# 3. Achieve the goal (receiving program funds through the above methods)
# 4. Get away with the goal, move the money, avoid detection.
#
# <html> <h3>
#     Put yourself in the shoes of an Investigator or FWA Data Scientist. An investigator's goal would be to:
# </h3> </html>
#
# 1. Know the limitations, loopholes and weaknesses of a program or system.
# 2. Understand known fraud schemes-- what have we seen in similar programs?
# 3. Have a SME-- if you're looking for fraud in a financial dataset, it may do well to have an account SME to help spot irregularities.
# 4. Understand the population of data-- what should things look like? What rules or trends are evident? What do the outliers look like?

# %% [markdown]
# ## Why is Data Science important for Fraud, Waste & Abuse problems?
#
# * Having tools to uncover what’s not obvious through manual review/plain sight is impactful and empowering for businesses, agencies, and personal research.
# * Provides structure to unstructured investigation
#
# > **Data Science** is a subset of tools that you pull out of toolbox when the situation makes sense. Know when to use which tools to evaluate the situation.
#
# Example: for a large set of unstructured data collected over a long time with chronological fields, it may make sense to do a Time Series analysis. For any data analytics in search of Fraud, Waste and Abuse For an application dataset supporting a program with eligibility rules, simple duplicate identification and fuzzy matching may be the most immediately impactful.

# %% [markdown]
# ## Scholarship Application Duplicate Identification:

# %%
# Import necessary libraries
import pandas as pd

# Sample dataset
data = {'Name': ['John', 'Jane', 'John', 'Bob', 'Alice', 'Jane', 'Alice']}
df = pd.DataFrame(data)

# Display the original dataset
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#     Name
# 0   John
# 1   Jane
# 2   John
# 3    Bob
# 4  Alice
# 5   Jane
# 6  Alice

# %%
# Identify duplicate names
duplicate_names = df[df.duplicated('Name')]

# Display duplicate names
print("\nDuplicate Names:")
print(duplicate_names)
# Out:
# Duplicate Names:
#     Name
# 2   John
# 5   Jane
# 6  Alice

# %%
# Count the occurrences of each name
name_counts = df['Name'].value_counts()

# Display names with more than one occurrence (potential duplicates)
potential_duplicates = name_counts[name_counts > 1]
print("\nPotential Duplicates:")
print(potential_duplicates)
# Out:
# Potential Duplicates:
# Name
# John     2
# Jane     2
# Alice    2
# Name: count, dtype: int64

# %%
# Additional information about duplicates
print("\nAdditional Information:")
for name, count in potential_duplicates.items():
    duplicate_indices = df[df['Name'] == name].index.tolist()
    print(f"Name: {name}, Count: {count}, Indices: {duplicate_indices}")
# Out:
# Additional Information:
# Name: John, Count: 2, Indices: [0, 2]
# Name: Jane, Count: 2, Indices: [1, 5]
# Name: Alice, Count: 2, Indices: [4, 6]

# %% [markdown]
# ## Question: What could duplicate names in an application dataset imply?

# %% [markdown]
# ## Anomaly Detection:

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# Generate a synthetic dataset with anomalies
np.random.seed(42)
normal_data = np.random.normal(loc=0, scale=1, size=(900, 2))
anomaly_data = np.random.normal(loc=4, scale=1, size=(100, 2))
data = np.vstack([normal_data, anomaly_data])
labels = np.hstack([np.zeros(900), np.ones(100)])

# Create a DataFrame
df = pd.DataFrame(data, columns=['Feature1', 'Feature2'])
df['Label'] = labels

# Display the first few rows of the dataset
print("First Few Rows of the Dataset:")
print(df.head())
# Out:
# First Few Rows of the Dataset:
#    Feature1  Feature2  Label
# 0  0.496714 -0.138264    0.0
# 1  0.647689  1.523030    0.0
# 2 -0.234153 -0.234137    0.0
# 3  1.579213  0.767435    0.0
# 4 -0.469474  0.542560    0.0

# %%
# Feature scaling (standardization)
scaler = StandardScaler()
df[['Feature1', 'Feature2']] = scaler.fit_transform(df[['Feature1', 'Feature2']])

# Select features for the model
features = df.drop('Label', axis=1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Train the Local Outlier Factor model
model = LocalOutlierFactor(contamination=0.05)  # Adjust contamination based on expected anomaly rate
y_pred_train = model.fit_predict(X_train)
y_pred_test = model.fit_predict(X_test)

# Convert predictions to binary labels (1 for anomaly, -1 for normal)
y_pred_train_binary = np.where(y_pred_train == 1, 0, 1)
y_pred_test_binary = np.where(y_pred_test == 1, 0, 1)

# Evaluate the model on the training set
print("\nTraining Set - Classification Report:")
print(classification_report(y_train, y_pred_train_binary))

# Evaluate the model on the test set
print("\nTest Set - Classification Report:")
print(classification_report(y_test, y_pred_test_binary))
# Out:
# Training Set - Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.96      0.93       721
#          1.0       0.28      0.14      0.18        79
#
#     accuracy                           0.88       800
#    macro avg       0.59      0.55      0.56       800
# weighted avg       0.85      0.88      0.86       800
#
#
# Test Set - Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.96      0.93       179
#          1.0       0.20      0.10      0.13        21
#
#     accuracy                           0.86       200
#    macro avg       0.55      0.53      0.53       200
# weighted avg       0.83      0.86      0.84       200

# %%
# Visualize the decision function for the test set
plt.figure(figsize=(16, 8))
plt.rcParams.update({'font.size': 50})

# Inlier regions (white background)
inliers = y_pred_test == 1
plt.scatter(X_test.iloc[inliers, 0], X_test.iloc[inliers, 1], c='white', edgecolors='k', s=100, label='Inliers')

# Outlier regions (colored background)
outliers = y_pred_test == -1
plt.scatter(X_test.iloc[outliers, 0], X_test.iloc[outliers, 1], c='red', edgecolors='k', s=100, label='Outliers')

plt.title('Local Outlier Factor - Anomaly Detection', size = 20)
plt.xlabel('Feature 1', size = 20)
plt.ylabel('Feature 2', size = 20)
plt.legend(prop = {'size':15})
plt.show()

# %% [markdown]
# ## Question: How could anomalies be useful in detecting Fraud, Waste and Abuse?

# %% [markdown]
# ## Conclusion Statements:
#
# > ### Fraud, Waste and Abuse detection is just one of many fun and exciting applications of Data Science.

# %% [markdown]
# # III. Data Science Models in Action

# %% [markdown]
# ## Forest Fires in the USA
#
# > <h3> "Nearly 85 percent* of wildland fires in the United States are caused by humans. Human-caused fires result from campfires left unattended, the burning of debris, equipment use and malfunctions, negligently discarded cigarettes, and intentional acts of arson." (https://www.nps.gov/articles/wildfire-causes-and-evaluation.htm) </h3>
#
# <div>
#     <img src="images/this_is_fine.png" width="600"/>
# </div>
#
# ## What can we do?

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import jinja2
plt.style.use('seaborn')

from IPython.display import IFrame

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import r2_score, mean_squared_error, explained_variance_score,mean_absolute_error
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

import tensorflow as tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.utils import np_utils
from keras.constraints import maxnorm
from keras.wrappers.scikit_learn import KerasRegressor

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ## Understanding the Problem:

# %% [markdown]
# > ### This is a difficult regression task, where the aim is to predict the burned area of forest fires, in the northeast region of Portugal, by using meteorological and other data (see details at: http://www.dsi.uminho.pt/~pcortez/forestfires).

# %% [markdown]
# ## Understanding the Data:
#
# |Column Name|Definition|
# |:--:|:--|
# | X | x-axis spatial coordinate within the Montesinho park map: 1 to 9|
# | Y | y-axis spatial coordinate within the Montesinho park map: 2 to 9|
# | month | month of the year: ‘jan’ to ‘dec’|
# | day | day of the week: ‘mon’ to ‘sun’|
# | FFMC | FFMC (Fine Fuel Moisture Code) index from the FWI system: 18.7 to 96.20|
# | DMC | DMC (Duff Moisture Code) index from the FWI system: 1.1 to 291.3|
# | DC | DC (Drought Code) index from the FWI system: 7.9 to 860.6|
# | ISI | ISI (Initial Spread Index) index from the FWI system: 0.0 to 56.10|
# | temp | temperature in Celsius degrees: 2.2 to 33.30|
# | RH | relative humidity in %: 15.0 to 100|
# | wind | wind speed in km/h: 0.40 to 9.40|
# | rain | outside rain in mm/m2 : 0.0 to 6.4|
# | area | the burned area of the forest (in ha): 0.00 to 1090.84|

# %% [markdown]
# ## Read in the Data

# %%
df = pd.read_csv("data/forestfires.csv")
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %% [markdown]
# ## Feature Engineer & Scale

# %%
# Create new features 
df['size_category'] = np.where(df['area'] > 6, '1', '0')
df['size_category']= pd.to_numeric(df['size_category'])

df['day'] = ((df['day'] == 'sun') | (df['day'] == 'sat'))
df = df.rename(columns = {'day' : 'is_weekend'})

#Encode Months as numeric values
month_vals = {'jan': 1,'feb': 2,'mar': 3,'apr': 4,'may': 5,'jun': 6,'jul': 7,'aug': 8,'sep': 9,'oct': 10,'nov': 11,'dec': 12}
df['month'] = df['month'].map(month_vals)

# visualizing
sns.countplot(df['size_category'])
plt.title('Bar plot of Area Split Into Size Categories')
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]
# ...

# %%
# natural logarithm scaling (+1 to prevent errors at 0)
df.loc[:, ['rain', 'area']] = df.loc[:, ['rain', 'area']].apply(lambda x: np.log(x + 1), axis = 1)

# visualizing
fig, ax = plt.subplots(2, figsize = (9, 11))
ax[0].hist(df['rain'])
ax[0].title.set_text('histogram of rain')
ax[1].hist(df['area'])
ax[1].title.set_text('histogram of area')

# %% [markdown]
# ## Correlation Plot

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize=(14,10))  
sns.heatmap(corr,annot=True, linewidths=.5, ax = ax)
# Out:
# <Axes: >

# %% [markdown]
# ## Feature Selection & Train/Test Split

# %%
# Assign feature columns and target variable (labels)
features = df.drop(['size_category'], axis = 1)
labels = df['size_category'].values.reshape(-1, 1)

#Set the train/test split using 80/20
X_train, X_test, y_train, y_test = train_test_split(features,labels, test_size = 0.2, random_state = 42)

# fitting scaler
sc_features = StandardScaler()

# transforming features
X_test = sc_features.fit_transform(X_test)
X_train = sc_features.transform(X_train)

# features
X_test = pd.DataFrame(X_test, columns = features.columns)
X_train = pd.DataFrame(X_train, columns = features.columns)

# labels
y_test = pd.DataFrame(y_test, columns = ['size_category'])
y_train = pd.DataFrame(y_train, columns = ['size_category'])
X_train.head()
# Out:
#           X         Y     month  is_weekend      FFMC       DMC        DC  \
# 0 -0.293766 -0.927776  0.672240    1.404076  0.342959 -0.060220  0.867158
# 1 -0.293766 -0.161993  0.672240   -0.712212 -0.057456  0.370353  0.600021
# 2 -1.130796  0.603791  0.232536   -0.712212  0.312158  0.834731  0.483714
# 3 -0.712281 -0.161993  0.232536   -0.712212  1.544206  1.341810  0.537142
# 4  0.124750 -0.161993 -2.405688    1.404076 -1.320305 -1.602809 -2.022846
#
#         ISI      temp        RH      wind      rain      area
# 0 -0.249015  0.784070 -1.071784 -0.054362 -0.137348  0.219260
# 1 -0.465731 -0.203920 -0.279375 -1.042369 -0.137348  0.177491
# 2  0.664288  0.221938  0.248898 -0.054362 -0.137348  0.180797
# 3  0.664288  2.283090 -1.071784 -1.042369 -0.137348  1.087255
# 4 -0.945602 -1.106740  0.645102 -1.042369 -0.137348  0.578923

# %% [markdown]
# ## Train & Evaluate Multiple Models

# %%
num_instances = len(X_train)

models = []
models.append(('LiR', LinearRegression()))
models.append(('Ridge', Ridge()))
models.append(('Lasso', Lasso()))
models.append(('ElasticNet', ElasticNet()))
models.append(('Bag_Re', BaggingRegressor()))
models.append(('RandomForest', RandomForestRegressor()))
models.append(('ExtraTreesRegressor', ExtraTreesRegressor()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('SVM', SVR()))

# Evaluations
evaluations = []

for name, model in models:
    # Fit the model
    model.fit(X_train, y_train)
    
    predictions = model.predict(X_test)
    
    # Evaluate the model
    score = explained_variance_score(y_test, predictions)
    mae = mean_absolute_error(predictions, y_test)
    
    temp_df = pd.DataFrame({'Model': name,
                            'Variance Score': score,
                            'Mean Absolute Error': mae}, index = [0])
    evaluations.append(temp_df)

print("We look for the model with the highest explained variance score and the smallest MAE:")
eval_df = pd.concat(evaluations).reset_index().drop(columns = ['index'])
eval_df = eval_df.sort_values(by ="Mean Absolute Error")
eval_df = eval_df.style.highlight_max(subset=eval_df.columns[1]).highlight_min(subset=eval_df.columns[-1])
eval_df
# Out:
# We look for the model with the highest explained variance score and the smallest MAE:
# <style type="text/css">
# #T_35c35_row0_col1, #T_35c35_row0_col2, #T_35c35_row1_col1, #T_35c35_row1_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_35c35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35c35_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_35c35_level0_col1" class="col_heading level0 col1" >Variance Score</th>
#       <th id="T_35c35_level0_col2" class="col_heading level0 col2" >Mean Absolute Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35c35_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_35c35_row0_col0" class="data row0 col0" >Bag_Re</td>
#       <td id="T_35c35_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_35c35_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
# ...

# %%
def baseline_model():
    model = Sequential()
    # input layer + 1st hidden layer
    model.add(Dense(6, input_dim=13, activation='relu'))
    # 2nd hidden layer
    model.add(Dense(6, activation='relu'))
    # output layer
    model.add(Dense(6, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    print(model.summary())
    return(model)

# Define the baseline model
model = baseline_model()

# Compile Model
model.compile(optimizer = 'adam', metrics=['accuracy'], loss ='binary_crossentropy')

# Train Model
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), batch_size = 10, epochs = 100)

# Evaluate the Baseline Model
_, train_acc = model.evaluate(X_train, y_train, verbose=0)
_, valid_acc = model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Valid: %.3f' % (train_acc, valid_acc))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 6)                 84
#
#  dense_9 (Dense)             (None, 6)                 42
#
#  dense_10 (Dense)            (None, 6)                 42
#
#  dropout_2 (Dropout)         (None, 6)                 0
#
#  dense_11 (Dense)            (None, 1)                 7
#
# ...
# Total params: 175
# Trainable params: 175
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 42/42 [==============================] - 1s 5ms/step - loss: 1.2966 - accuracy: 0.6199 - val_loss: 0.5450 - val_accuracy: 0.7692
# Epoch 2/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.3161 - accuracy: 0.6513 - val_loss: 0.5294 - val_accuracy: 0.7692
# Epoch 3/100
# ...

# %%
plt.figure(figsize=[8,5])
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.legend()
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves Epoch 100, Batch Size 10', fontsize=16)
plt.show()

# %%
def init_model():
    # define model
    model = Sequential()
    model.add(Dense(6, input_dim=13, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    model.compile(optimizer ='adam',
    metrics=['accuracy'],
    loss = 'binary_crossentropy')
    return model

# init model
model = init_model()

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=150)

# model checkpoint
mc = ModelCheckpoint('models/best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# fitting model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=250, verbose=0, batch_size=6, 
                    callbacks = [es, mc])
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.73077, saving model to models/best_model.h5
#
# Epoch 2: val_accuracy did not improve from 0.73077
#
# Epoch 3: val_accuracy did not improve from 0.73077
#
# Epoch 4: val_accuracy did not improve from 0.73077
#
# Epoch 5: val_accuracy did not improve from 0.73077
#
# Epoch 6: val_accuracy improved from 0.73077 to 0.74038, saving model to models/best_model.h5
#
# Epoch 7: val_accuracy did not improve from 0.74038
#
# Epoch 8: val_accuracy did not improve from 0.74038
#
# Epoch 9: val_accuracy did not improve from 0.74038
#
# Epoch 10: val_accuracy did not improve from 0.74038
#
# Epoch 11: val_accuracy did not improve from 0.74038
#
# Epoch 12: val_accuracy did not improve from 0.74038
#
# Epoch 13: val_accuracy improved from 0.74038 to 0.75000, saving model to models/best_model.h5
#
# Epoch 14: val_accuracy improved from 0.75000 to 0.75962, saving model to models/best_model.h5
#
# Epoch 15: val_accuracy did not improve from 0.75962
#
# ...

# %%
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='valid')
plt.legend()
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Loss Curves', fontsize=16)
plt.show()

# %%
plt.figure(figsize=[8,5])
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.legend()
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves', fontsize=16)
plt.show()

# %% [markdown]
# ## Conclusion Statements:
#
# > ### Data Science has the power to affect CHANGE. Find out what you care about and see how you can make the world a better place for yourself and others.

# %% [markdown]
# # Want to learn more?
#
# <html><h3>
#
# > * What is Artificial Intelligence? https://rb.gy/tm1xbd
# > * Top 10 Machine Learning Algorithms for Beginners https://rb.gy/cosidk
# > * The Hidden Dangers of Data Science https://rb.gy/7aiwan
# > * The Gren AI Foundation https://tgaif.org/
# > * Code Academy https://www.codecademy.com/
# > * DataCamp https://www.datacamp.com/
#
# </h3></html>
